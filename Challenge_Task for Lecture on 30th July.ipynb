# %%
import pandas as pd
import datetime

# %%
df= pd.read_csv(r"C:\Users\w10\OneDrive\Desktop\Ineuron Data\Pandas 2nd Lecture\AgentPerformance.csv")

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df['New_Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df['Days'] = df['New_Date'].dt.day_name()

# %% [markdown]
# Q1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
average_rating=df.groupby(['Agent Name','Days'])['Average Rating'].mean()

# %%
[average_rating.count]
# Out:
# [<bound method Series.count of Agent Name  Days
#  Abhishek    Friday       0.0000
#              Monday       0.0000
#              Saturday     0.0000
#              Sunday       0.0000
#              Thursday     0.0000
#                            ...
#  Zeeshan     Saturday     0.8280
#              Sunday       1.2125
#              Thursday     3.1700
#              Tuesday      0.9375
#              Wednesday    3.3575
#  Name: Average Rating, Length: 490, dtype: float64>]

# %% [markdown]
# Q2 .Total working days for each agents

# %%
df.groupby('Agent Name')['Days'].count()
# Out:
# Agent Name
# Abhishek         30
# Aditya           30
# Aditya Shinde    30
# Aditya_iot       30
# Amersh           30
#                  ..
# Uday Mishra      30
# Vasanth P        30
# Vivek            30
# Wasim            30
# Zeeshan          30
# Name: Days, Length: 70, dtype: int64

# %% [markdown]
# Q3. Total query that you hvae taken

# %%
df.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %% [markdown]
# Q4. total Feedback that you have received

# %%
df.groupby("Agent Name")["Total Feedback"].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %% [markdown]
# Q5. a agent name who have average rating between 3.5 to 4

# %%
df[(df["Average Rating"]>3.5) & (df["Average Rating"]<=4)]["Agent Name"]
# Out:
# 4                    Swati
# 10             Manjunatha A
# 73      Boktiar Ahmed Bappy
# 76            Prateek _iot
# 78            Nandani Gupta
#                ...
# 1941         Jawala Prakash
# 2018          Sanjeev Kumar
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# 2097          Sanjeev Kumar
# Name: Agent Name, Length: 111, dtype: object

# %% [markdown]
# Q6 . Agent name who have rating lesss then 3.5

# %%
df[(df["Average Rating"]<3.5)]["Agent Name"]
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %% [markdown]
# Q7 . agent name who have rating more then 4.5

# %%
df[(df["Average Rating"]>4.5)]["Agent Name"]
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %% [markdown]
# Q8 . how many feedaback agents have received more then 4.5 average

# %%
df[(df["Average Rating"]>4.5)][["Agent Name","Total Feedback"]]
# Out:
#               Agent Name  Total Feedback
# 2             Ameya Jain              11
# 3          Mahesh Sarade               7
# 5                Mukesh                8
# 6        Saikumarreddy N              12
# 7          Sanjeev Kumar               6
# ...                  ...             ...
# 2100      Shubham Sharma              13
# 2101       Jaydeep Dixit              13
# 2102  Shivananda Sonwane              14
# 2103      Khushboo Priya              18
# 2104     Hrisikesh Neogi               9
#
# [307 rows x 2 columns]

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %% [markdown]
# Q9 . average weekly response time for each agent

# %%
df["Average_Response_in_Seconds"]= df['Average Response Time'].str.split(':').apply(lambda x: int(x[1]) * 60 + int(x[2]))

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df.groupby(["Agent Name","Days"])["Average_Response_in_Seconds"].mean()
# Out:
# Agent Name  Days
# Abhishek    Friday         0.00
#             Monday         0.00
#             Saturday       0.00
#             Sunday         0.00
#             Thursday       0.00
#                           ...
# Zeeshan     Saturday      45.80
#             Sunday        20.25
#             Thursday      69.75
#             Tuesday       26.00
#             Wednesday    101.50
# Name: Average_Response_in_Seconds, Length: 490, dtype: float64

# %% [markdown]
# Q10 . Average weekely resolution time for each agents

# %%
df["Average_Resolution_in_Seconds"]= df["Average Resolution Time"].str.split(':').apply(lambda x: int(x[1]) * 60 + int(x[2]))

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df.groupby(["Agent Name","Days"])["Average_Resolution_in_Seconds"].mean()
# Out:
# Agent Name  Days
# Abhishek    Friday         0.00
#             Monday         0.00
#             Saturday       0.00
#             Sunday         0.00
#             Thursday       0.00
#                           ...
# Zeeshan     Saturday     219.20
#             Sunday       301.00
#             Thursday     751.75
#             Tuesday      387.50
#             Wednesday    801.00
# Name: Average_Resolution_in_Seconds, Length: 490, dtype: float64

# %% [markdown]
# Q11 . list of all agents name

# %%
df["Agent Name"].unique()
# Out:
# array(['Prerna Singh', 'Nandani Gupta', 'Ameya Jain', 'Mahesh Sarade',
#        'Swati ', 'Mukesh ', 'Saikumarreddy N', 'Sanjeev Kumar',
#        'Shubham Sharma', 'Nishtha Jain', 'Manjunatha A', 'Khushboo Priya',
#        'Suraj S Bilgi', 'Harikrishnan Shaji', 'Hrisikesh Neogi',
#        'Shivan K', 'Sowmiya Sivakumar', 'Madhulika G', 'Mithun S',
#        'Hitesh Choudhary', 'Sanjeevan ', 'Anirudh ', 'Shiva Srivastava',
#        'Dibyanshu ', 'Ashish ', 'Uday Mishra', 'Aditya Shinde',
#        'Jayant Kumar', 'Aditya_iot ', 'Prabir Kumar Satapathy',
#        'Saurabh Shukla', 'Wasim ', 'Samprit ', 'Maitry ', 'Abhishek ',
#        'Rishav Dash', 'Aravind ', 'Tarun ', 'Muskan Garg', 'Ankit Sharma',
#        'Bharath ', 'Ashad Nasim', 'Vasanth P', 'Aditya ', 'Amersh ',
#        'Sandipan Saha', 'Ineuron Intelligence ', 'Mahak ', 'Mukesh Rao ',
#        'Zeeshan ', 'Anurag Tiwari', 'Ankitjha ', 'Saif Khan',
#        'Jaydeep Dixit', 'Sudhanshu Kumar', 'Maneesh ', 'Hyder Abbas',
# ...

# %% [markdown]
# Q12 . percentage of chat on which they have received a feedback

# %%
df["%_Of_Feedbacks_Received"] = df["Total Feedback"] / df["Total Chats"] * 100

# %%
df.groupby(['Agent Name','Total Chats'])["%_Of_Feedbacks_Received"]

# %%
df.head(50)
# Out:
#     SL No       Date              Agent Name  Total Chats  \
# 0       1  7/30/2022            Prerna Singh           11
# 1       2  7/30/2022           Nandani Gupta           11
# 2       3  7/30/2022              Ameya Jain           14
# 3       4  7/30/2022           Mahesh Sarade           14
# 4       5  7/30/2022                  Swati            14
# 5       6  7/30/2022                 Mukesh             9
# 6       7  7/30/2022         Saikumarreddy N           15
# 7       8  7/30/2022           Sanjeev Kumar           12
# 8       9  7/30/2022          Shubham Sharma           13
# 9      10  7/30/2022            Nishtha Jain           20
# 10     11  7/30/2022            Manjunatha A           11
# 11     12  7/30/2022          Khushboo Priya           20
# 12     13  7/30/2022           Suraj S Bilgi           20
# 13     14  7/30/2022      Harikrishnan Shaji           13
# 14     15  7/30/2022         Hrisikesh Neogi           28
# ...

# %%
df1= pd.read_csv(r"C:\Users\w10\OneDrive\Desktop\Ineuron Data\Pandas 2nd Lecture\AgentLogingReport.csv")

# %%
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time  Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
# ..     ...                 ...        ...        ...         ...       ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28  05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32  06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55  05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33  05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  10:00:00
#
# [1000 rows x 6 columns]

# %%
df1.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df1["Date"] = pd.to_datetime(df1["Date"])

# %%
df1.dtypes
# Out:
# SL No                   int64
# Agent                  object
# Date           datetime64[ns]
# Login Time             object
# Logout Time            object
# Duration               object
# dtype: object

# %%
df1["Week"] = df1["Date"].dt.isocalendar().week

# %% [markdown]
# Q13 . Total contributation hour for each and every agents weekly basis

# %%
df1["Duration_in_Seconds"]= df1["Duration"].str.split(':').apply(lambda x: int(x[0]) * 3600 + int(x[1]) * 60  + int(x[2]))

# %%
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time  Duration  \
# 0        1  Shivananda Sonwane 2022-07-30   15:35:29    17:39:39  02:04:10
# 1        2      Khushboo Priya 2022-07-30   15:06:59    15:07:16  00:00:17
# 2        3       Nandani Gupta 2022-07-30   15:04:24    17:31:07  02:26:42
# 3        4     Hrisikesh Neogi 2022-07-30   14:34:29    15:19:35  00:45:06
# 4        5              Mukesh 2022-07-30   14:03:15    15:11:52  01:08:36
# ..     ...                 ...        ...        ...         ...       ...
# 995    996        Manjunatha A 2022-07-20   09:03:51    15:02:28  05:58:37
# 996    997             Bharath 2022-07-20   09:00:49    15:01:32  06:00:43
# 997    998      Khushboo Priya 2022-07-20   08:59:20    14:26:55  05:27:34
# 998    999        Nishtha Jain 2022-07-20   08:43:55    14:00:33  05:16:38
# 999   1000               Tarun 2022-07-01   01:52:47    12:01:07  10:00:00
#
#      Week  Duration_in_Seconds
# 0      30                 7450
# ...

# %%
df1.groupby(["Agent","Week"])["Duration_in_Seconds"].mean()
# Out:
# Agent          Week
# Aditya Shinde  30        130.000000
# Aditya_iot     29       7314.333333
#                30       5781.500000
# Amersh         30       2757.500000
# Ameya Jain     29      12385.571429
#                            ...
# Tarun          26      36000.000000
# Wasim          29       7850.222222
#                30       9344.818182
# Zeeshan        29      14656.500000
#                30      22195.000000
# Name: Duration_in_Seconds, Length: 89, dtype: float64

# %% [markdown]
# Q14. total percentage of active hour for a month

# %%
df1["Duration_in_Seconds"] / df1.groupby("Agent")['Duration_in_Seconds'].transform('sum')
# Out:
# 0      0.041987
# 1      0.000108
# 2      0.060863
# 3      0.013057
# 4      0.128392
#          ...
# 995    0.144809
# 996    0.125049
# 997    0.125336
# 998    0.120340
# 999    1.000000
# Name: Duration_in_Seconds, Length: 1000, dtype: float64
